# %%
import matplotlib.pyplot as plt

# %%
# Runs in IPL
x=[735,684,659,602,555,549,530]

# Players
y=['Williamson','Rishabh Pant','L Rahul','Raydu','Watson','Buttler','Kohli']

plt.xlabel('runs')
plt.ylabel("players")

plt.bar(y,x,label='IPL Runs')

plt.grid(color='y')

plt.legend()
plt.show()
