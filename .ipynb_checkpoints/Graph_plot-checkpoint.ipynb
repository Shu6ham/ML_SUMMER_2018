# %%
import matplotlib.pyplot as plt

# %%
# Runs in IPL
x=[735,684,659,602,555,549,530]

# Players
y=['Williamson','Rishabh Pant','L Rahul','Raydu','Watson','Buttler','Kohli']

plt.xlabel('runs')
plt.ylabel("players")

plt.bar(y,x,label='IPL Runs')

plt.grid(color='y')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Years
x=[2012,2013,2014,2015,2016,2017]

# GDP Rate
y=[5.46,6.39,7.41,8.16,7.11,6.74]

plt.xlabel("Years")
plt.ylabel("Growth Rate")

plt.bar(x,y,label='GDP')

#plt.grid()

plt.legend()
plt.show()
